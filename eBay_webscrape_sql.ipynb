# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import os
from multiprocessing import Pool
import pymysql
import pandas as pd

# %% [markdown]
# ## Buy-it-now listings of <"canon eos 5d">.

# %%
def getLinks(qrkw, page, ipg=100, BIN=True):
    """
    The function takes search item and page number, and returns a list of links for sponsored and nonsponsored items.
    
    PARAM qrkw: str, search item;
    PARAM page: int, page number;
    PARAM ipg: int, item per page, default=100;
    PARAM BIN: boolean, buy-it-now listing, default=True;
    
    RETURN a list of url links for sponsored and nonsponsored items on the selected page.
    """
    if BIN:
        LH_BIN = 1
    else:
        LH_BIN = 0
    
    base_url = "https://www.ebay.com/sch/i.html?"
    url = base_url + "_nkw=" + qrkw + "&LH_BIN=" + str(LH_BIN) + "&_ipg=" + str(ipg) + "&_pgn=" + str(page)
    r = requests.get(url, headers={'user-agent': 'Mozilla/5.0'})
    soup_r = BeautifulSoup(r.content)
    links = soup_r.find_all("a", class_="s-item__link")
    sponsored_links=[]
    nonsponsored_links=[]
    for link in links:
        simp_link = re.sub("(.*)\\?.*", r"\1", link['href'])
        tag_text = link.find_all('span')[0].get_text()
        if re.search('.*S.*P.*O.*N.*S.*O.*R.*E.*D.*', tag_text):
            sponsored_links.append(simp_link)
        else:
            nonsponsored_links.append(simp_link)
            
    return sponsored_links, nonsponsored_links

# %%
# Get all the sponsored and nonsponsored URLs of a page, save them into a list.
kw = "canon eos 5d"
sponsored_each = []
nonsponsored_each = []
for i in range(1,11):
    temp_sp, temp_nsp = getLinks(kw, i)
    sponsored_each.append(temp_sp)
    nonsponsored_each.append(temp_nsp)
    print("URLs retrieved, Page",i)
    time.sleep(2)
# Out:
# URLs retrieved, Page 1
# URLs retrieved, Page 2
# URLs retrieved, Page 3
# URLs retrieved, Page 4
# URLs retrieved, Page 5
# URLs retrieved, Page 6
# URLs retrieved, Page 7
# URLs retrieved, Page 8
# URLs retrieved, Page 9
# URLs retrieved, Page 10

# %%
# Write all retrieved URLs into two txt files.
sponsored = []
for items in sponsored_each:
    for i in items:
        sponsored.append(i)
        
with open("sponsored.txt", "w") as file:
    for item in sponsored:
        file.write('%s\n' % item)
        
# Write all sponored and non-sponsored URLs into a txt file.
nonsponsored = []
for items in nonsponsored_each:
    for i in items:
        nonsponsored.append(i)
        
with open("non-sponsored.txt", "w") as file:
    for item in nonsponsored:
        file.write('%s\n' % item)

# %%
# Create directories for "sponsored" and "nonsponsored" pages.
try:
    path_sponsored = os.getcwd() + "/sponsored"
    path_nonsponsored = os.getcwd() + "/non-sponsored"
    os.makedirs(path_sponsored)
    os.makedirs(path_nonsponsored)
except OSError:
    print ("Creation of the directory failed")
else:
    print ("Successfully created the directory.")
# Out:
# Successfully created the directory.

# %%
def savehtm_sp(url):
    """
    The function takes the url and save it locally in a html file.
    
    PARAM url: str, url link;
    """
    try:
        item_id = re.search(r'[0-9]{12}', url)[0]
        soup_temp = BeautifulSoup(requests.get(url, headers={'user-agent': 'Mozilla/5.0'}).content) 
        with open(os.getcwd() + "/sponsored/" + item_id+".htm", "w") as f:
            f.write(str(soup_temp))
        #print("============================")
        #print(item_id,"Saved")
        time.sleep(2)
        
    except requests.ConnectionError as e:
        print("OOPS!! Connection Error. Make sure you are connected to Internet. Technical Details given below.\n")
        print(str(e))
    except requests.Timeout as e:
        print("OOPS!! Timeout Error")
        print(str(e))
    except requests.RequestException as e:
        print("OOPS!! General Error")
        print(str(e))
    except KeyboardInterrupt:
        print("Someone closed the program")

# %%
# put all sponsored links into a list.
sponsored_links = []
with open("sponsored.txt", "r") as file:
    for link in file:
        sponsored_links.append(link.replace('\n',''))

# %%
# using parallel processing to save html in sponsored folder.
p = Pool(10)  # Processing 10 links at a time.
save_sptml = p.map(savehtm_sp, sponsored_links)
p.terminate()
p.join()

# %%
def savehtm_non(url):
    """
    The function takes the url and save it locally in a html file.
    
    PARAM url: str, url link;
    """
    try:
        item_id = re.search(r'[0-9]{12}', url)[0]
        soup_temp = BeautifulSoup(requests.get(url, headers={'user-agent': 'Mozilla/5.0'}).content) 
        with open(os.getcwd() + "/non-sponsored/" + item_id + ".htm", "w") as f:
            f.write(str(soup_temp))
        #print("============================")
        #print(item_id,"Saved")
        time.sleep(2)
    
    except requests.ConnectionError as e:
        print("OOPS!! Connection Error. Make sure you are connected to Internet. Technical Details given below.\n")
        print(str(e))
    except requests.Timeout as e:
        print("OOPS!! Timeout Error")
        print(str(e))
    except requests.RequestException as e:
        print("OOPS!! General Error")
        print(str(e))
    except KeyboardInterrupt:
        print("Someone closed the program")

# %%
# put all nonsponsored links into a list.
nonsponsored = []
with open("non-sponsored.txt", "r") as file:
    for link in file:
        nonsponsored.append(link.replace('\n',''))

# %%
# using parallel processing to save html in non-sponsored folder.
p = Pool(10)  # Processing 10 links at a time.
save_nsphtm = p.map(savehtm_non, nonsponsored)
p.close()
p.terminate()
p.join()

# %% [markdown]
# ## Extract item information

# %%
def extractInfo(html):
    """
    The function takes the html file from sponsored and return a dictionary containing item information.
    
    PARAM str: html file name;
    
    RETURN dict: item_id, item_title, item_price, condition, items_sold, seller_name, seller_score,
                 best_offer, returns_allowed, shipping_cal, shipping_cost
    """
    # soup object to start with
    soup_pgn = BeautifulSoup(open(os.getcwd() + "/sponsored/" + html))
    
    # this for sponsored items only.
    sponsored = True
    
    # get item id from the html file name
    item_id = int(re.search(r'[0-9]{12}', html)[0])
    
    # get the item title by looking at the first header with id=itemTitle, stripping out unwanted characters
    item_title = soup_pgn.find('h1',{'id':'itemTitle'}).get_text().replace('Details about  \xa0','').replace('\xa0','')
    
    # look for price summary span with id=prcIsum, when it is not in USD, use price in span with id=convbinPrice
    # when it is in USD, just use the price; or when it is on sale, use discounted price
    # for both situations, convert US dollars into US cents
    if soup_pgn.find('span',{'id':'prcIsum'}):
        if soup_pgn.find('span',{'id':'convbinPrice'}):
            raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'convbinPrice'}).get_text().strip().replace(',',''))[0]
            item_price = int(float(raw_price_text)*100)
        else:
            raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'prcIsum'}).get_text().strip().replace(',',''))[0]
            item_price = int(float(raw_price_text)*100)
    else:
        raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'mm-saleDscPrc'}).get_text().strip().replace(',',''))[0]
        item_price = int(float(raw_price_text)*100)
    
    # look for condition in div with id=vi-itm-cond, if not listed, return None.
    condition = None if soup_pgn.find('div',{'id':'vi-itm-cond'})==None else soup_pgn.find('div',{'id':'vi-itm-cond'}).get_text().strip()
    
    # look for item sold in span with a dedicated class attribute, convert into int, if not listed, return None.
    items_sold = None if soup_pgn.find('span', class_='vi-qtyS vi-bboxrev-dsplblk vi-qty-vert-algn vi-qty-pur-lnk')==None else int(soup_pgn.find('span', class_='vi-qtyS vi-bboxrev-dsplblk vi-qty-vert-algn vi-qty-pur-lnk').get_text().strip().replace(' sold',''))
    
    # look for seller name in span with class=mbg-nww, if not listed, return None.
    seller_name = None if soup_pgn.find('span', class_='mbg-nw')==None else soup_pgn.find('span', class_='mbg-nw').get_text()
    
    # look for seller_score in span with class=mbg-l, convert into int, if not listed, return None.
    seller_score = None if soup_pgn.findChild('span', class_='mbg-l').find('a')==None else int(soup_pgn.findChild('span', class_='mbg-l').find('a').get_text().strip())
    
    # look for better_offer availability in a with id=boBtn_btn, if not listed, return False.
    best_offer = False if soup_pgn.find('a',{'id':'boBtn_btn'})==None else True
    
    # look at the banner in span with id=vi-ret-accrd-txt, if it says not accept, return False, else True.
    if soup_pgn.find('span',{'id':'vi-ret-accrd-txt'}):
        if soup_pgn.find('span',{'id':'vi-ret-accrd-txt'}).get_text().strip()=='Seller does not accept returns':
            returns_allowed = False
        else:
            returns_allowed = True
    else:
        returns_allowed = True 
    
    # look for the shipping summary in the span with id=shSummary, if it says Calculate, return True, else False
    shipping_cal = True if soup_pgn.find('span',{'id':'shSummary'}).find('a').get_text()=='Calculate' else False
    # if shipping needs to be calculated, shipping cost is None
    if shipping_cal:
        shipping_cost = None
    # if not, look at the span with id=fshippingCost, 
    # if it says FREE, shipping cost=0, if not, return the US cents value for shipping
    elif soup_pgn.find('span',{'id':'fshippingCost'}):
            if soup_pgn.find('span',{'id':'fshippingCost'}).get_text().strip()=='FREE':
                shipping_cost = 0
            else:
                raw_text = soup_pgn.find('span',{'id':'fshippingCost'}).get_text().strip().replace(',','')
                shipping_cost = int(float(re.search(r'[0-9]+.[0-9]+', raw_text)[0])*100)
    # if it says fast and free, shipping cost=0
    elif soup_pgn.find('span',class_='vi-fnf-ship-txt fnfgreen'):
        shipping_cost = 0
    # if it is not in USD, use id=convetedPriceId, and return shipping cost in US cents
    elif soup_pgn.find('span',{'id':'convetedPriceId'}):
        raw_text = soup_pgn.find('span',{'id':'convetedPriceId'}).get_text().strip().replace(',','')
        shipping_cost = int(float(re.search(r'[0-9]+.[0-9]+', raw_text)[0])*100)
    # other situations like Local pick ups and needs contact seller, return None.
    else:
        shipping_cost = None
    
    
    info_keys = ['sponsored', 'item_id', 'item_title', 'item_price', 'condition', 'items_sold', 'seller_name', 'seller_score',
                 'best_offer', 'returns_allowed', 'shipping_cal', 'shipping_cost']
    info_vals = [sponsored, item_id, item_title, item_price, condition, items_sold, seller_name, seller_score,
                 best_offer, returns_allowed, shipping_cal, shipping_cost]
    item_dict = {info_keys[i]: info_vals[i] for i in range(len(info_keys))}
    
    return item_dict

# %%
# sponsored items' info using parallel computing
sponsored_files = os.listdir(os.getcwd() + "/sponsored/")
p = Pool(10)  # Processing 10 files at a time.
sponsored_items_info = p.map(extractInfo, sponsored_files)
p.terminate()
p.join()
sponsored_items_info
# Out:
# [{'sponsored': True,
#   'item_id': 202800626639,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + EF 24-70mm IS USM Lens Dual Battery Power Kit',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Beach Camera',
#   'seller_score': 354988,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 362370637186,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body Shutter: 698',
#   'item_price': 279999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372880508624,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-105mm USM Lens Bundle With Atomos Monitor Kit',
#   'item_price': 344900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 283030240569,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body with Battery Grip, and Microphone Bundle',
#   'item_price': 279800,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 112618511614,
#   'item_title': 'Canon EOS 5DSR / 5DS R / 5D SR Digital SLR DSLR Camera (Body) - 0582C002',
#   'item_price': 159995,
#   'condition': 'New',
#   'items_sold': 9,
#   'seller_name': 'thepixelhub',
#   'seller_score': 54651,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 184153951327,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera Body - 500 Shutter ONLY!! LBNIB!',
#   'item_price': 300000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'jdmstan',
#   'seller_score': 165,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323541247477,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera Body + 128GB Memory Card 4X 32 Bundle0058',
#   'item_price': 450960,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372842536081,
#   'item_title': 'Canon EOS 5D Mark IV with ED 24-105mm Lens and Flashpoint Zoom Li-on X TTL',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 382075786620,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm + Flash + 64GB + Filter Kit +  2yr Warranty',
#   'item_price': 226098,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 332047782462,
#   'item_title': 'Canon EOS 5D Mark IV with EF 24-70mm f/4L IS USM Lens #1483C018',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': 5,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372095357765,
#   'item_title': 'Canon EOS 5D Mark IV with EF 24-105mm f/4L IS II USM Lens #1483C010',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 143306342527,
#   'item_title': 'Canon EOS 5D Mark II 21.1 MP Digital SLR Camera (Body Only) by Original Owner.',
#   'item_price': 69696,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ustradeclub',
#   'seller_score': 184,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 282650764056,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body Only) with Battery Grip and 64GB Bundle',
#   'item_price': 279800,
#   'condition': 'New',
#   'items_sold': 8,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 254413079522,
#   'item_title': 'Canon EOS 5D Mk IV 30.4MP DSLR, 85mm f/1.2 II, 35mm f/1.4, ext 1.4x, cards, bag',
#   'item_price': 380000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'watchcollector59',
#   'seller_score': 204,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323984075839,
#   'item_title': '[Excellent+]Canon EOS 5D Mark II 21.1MP Body +BG-E6 Grip /New Battery Charger JP',
#   'item_price': 57999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'hertune_japan',
#   'seller_score': 499,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 6000},
#  {'sponsored': True,
#   'item_id': 333437896606,
#   'item_title': 'Canon EOS 5D Mark IV with EF 24-70mm f/4L IS USM Lens W/Canon 600EX II-RT Flash',
#   'item_price': 382800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 193332030865,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body (Intl Model) anty)',
#   'item_price': 204308,
#   'condition': 'Open box',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 352051791452,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm 1.8 & 70-300mm + Extra Battery + 2yr Warranty',
#   'item_price': 236398,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 184149692829,
#   'item_title': '[Mint] Canon EOS 5D Mark Ⅱ Body 30.4MP Digital SLR Camera Body 3Lens From Japan',
#   'item_price': 351799,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'worth-japan',
#   'seller_score': 124,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 274060660988,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP 50/28-80/75-300mm Lens Set [Exc+++] w/Box,8GB [jkh]',
#   'item_price': 95999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'camera_newlife_pro',
#   'seller_score': 400,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 254341220931,
#   'item_title': 'CANON EOS 5D Mark III EOS5DMK3 Digital Camera Body Tested Working Used',
#   'item_price': 126200,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kyoto-japan_mall',
#   'seller_score': 334,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 6290},
#  {'sponsored': True,
#   'item_id': 264617333653,
#   'item_title': 'Excellent++ Canon EOS 5D Mark II 21.1MP Digital SLR Camera Body from Japan',
#   'item_price': 69900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'eriku0817',
#   'seller_score': 1713,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4200},
#  {'sponsored': True,
#   'item_id': 392594588049,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-105mm USM Lens With DJI Ronin-S Essentials Kit',
#   'item_price': 368895,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 192717995778,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera (Body) + 64GB Memory Card (2X 32) Base Combo',
#   'item_price': 390113,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372732463224,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body-With Canon Speedlite 600EX II-RT Shoe Mount Flash',
#   'item_price': 307800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 352051689523,
#   'item_title': 'Canon EOS  5D Mark IV Camera + 50mm - 3 Lens Kit + 32GB + EXT BAT + 2yr Warranty',
#   'item_price': 225698,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 283770635272,
#   'item_title': 'Canon EOS 5D Mark II Digital Camera Body w/Box,Accessories [Excellent] Japan 351',
#   'item_price': 62600,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kura1018',
#   'seller_score': 432,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4000},
#  {'sponsored': True,
#   'item_id': 163769061537,
#   'item_title': 'SALE Canon EOS 5D Mark IV DSLR Camera + EF 24-105mm f/4L IS II USM Lens',
#   'item_price': 268900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'whiteribbonhouse',
#   'seller_score': 2011,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 362786955767,
#   'item_title': '[Near Mint] CANON EOS 5D MARK III BODY with 2 Battery Digital Camera From Japan',
#   'item_price': 126000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': True,
#   'item_id': 352051695929,
#   'item_title': 'Canon EOS  5D Mark IV Camera + 50mm STM + 75-300mm + 32GB + Flash + 2yr Warranty',
#   'item_price': 239898,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 303397366891,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera with EF24-105mm f/4L IS II USM Kit',
#   'item_price': 99999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'carnus',
#   'seller_score': 3297,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 391778421074,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm + 75-300mm + Flash + EXT BAT + 2yr Warranty',
#   'item_price': 232798,
#   'condition': 'New',
#   'items_sold': 2,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372722427541,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body Only) with Battery Grip & Monitor Bundle',
#   'item_price': 349800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372880508719,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body - Bundle With Atomos Shinobi 5.2" IPS Monitor Kit',
#   'item_price': 262900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 143506807337,
#   'item_title': 'Canon EOS 5d Digital SLR Mark II PLUS f2.8 100mm and f2 40mm lenses',
#   'item_price': 70000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mattshallenberger2',
#   'seller_score': 198,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 2000},
#  {'sponsored': True,
#   'item_id': 202498821833,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera Body + 256GB Memory Card 2X 128 Bundle0065',
#   'item_price': 458851,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323478534468,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera (Body) + 256GB Memory Card (2X 128) Base Combo',
#   'item_price': 403831,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 392064620645,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-105mm USM Lens With Free Mac Accessory Bundle',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 233385614176,
#   'item_title': '[Mint w/ Accessories] CANON EOS 5D Mark IV Digital SLR Camera Body from Japan',
#   'item_price': 284660,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kazuro46',
#   'seller_score': 412,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 3900},
#  {'sponsored': True,
#   'item_id': 202496684282,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera (Body) + 32GB Memory Card (1x 32) Base Combo',
#   'item_price': 387200,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 283759151573,
#   'item_title': 'Canon EOS 5D Mark II Body 21.1MP camera body / Focusing screen Japan [5027]',
#   'item_price': 57900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kyoto_camera',
#   'seller_score': 2155,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 391778335061,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm 1.8 - 3 Lens Kit + Flash + 64GB + yr Warranty',
#   'item_price': 232498,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 332425304852,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body with Canon Log With Free Accessory Bundle',
#   'item_price': 259900,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 254426539427,
#   'item_title': 'CANON EOS 5D Mark II Camera Lens Set EF 28-80 75-300 mm Excellent++ Used',
#   'item_price': 106000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kyoto-japan_mall',
#   'seller_score': 334,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4760},
#  {'sponsored': True,
#   'item_id': 371901503890,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body With Free Accessory Bundle #1483C002 A',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323886134223,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camera Black 22.3MP Body Only Excellent',
#   'item_price': 199999,
#   'condition': 'Used',
#   'items_sold': 1,
#   'seller_name': 'total-shop-japan-us',
#   'seller_score': 1567,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 352845586011,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm 1.8 STM + 70-300mm + 2yr Warranty - 64GB Kit',
#   'item_price': 262299,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 174182680492,
#   'item_title': 'Canon 1483C002 EOS 5D Mark IV DSLR Camera (Body Only) - International model',
#   'item_price': 290000,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'franxanatr_0',
#   'seller_score': 0,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 283591279182,
#   'item_title': '[NEAR MINT] Canon EOS 5D Mark II Digital SLR Camera W/ Battery grip Japan k278',
#   'item_price': 61191,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'solomon-camera-japan',
#   'seller_score': 274,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4999},
#  {'sponsored': True,
#   'item_id': 352958636202,
#   'item_title': 'EX+5 Canon EOS 5D 12.8MP Digital SLR Full-Frame w/Battery Grip BG-E4 From JAPAN ',
#   'item_price': 22900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japancameraclub',
#   'seller_score': 331,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4000},
#  {'sponsored': True,
#   'item_id': 153810510571,
#   'item_title': 'Super fast free shipping! Canon EOS 5D Mark III 22.3MPbody with extra!',
#   'item_price': 91900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'taoyuan107',
#   'seller_score': 2032,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 292278141824,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body) with Rode Microphone and 64GB Bundle',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': 5,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 352959870765,
#   'item_title': 'Excellent+++++ Canon EOS 5D 12.8MP Digital SLR Full-Frame Camera From JAPAN ',
#   'item_price': 24900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japancameraclub',
#   'seller_score': 331,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 3000},
#  {'sponsored': True,
#   'item_id': 202880122720,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body                        #788',
#   'item_price': 105400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142428,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 123902061728,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera Body {21.1 M/P}',
#   'item_price': 66310,
#   'condition': 'Seller refurbished',
#   'items_sold': None,
#   'seller_name': 'kehoutlet',
#   'seller_score': 99351,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 192884751857,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame DLSR Body, Kodak Printer and Accessory Bundle',
#   'item_price': 329900,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'ritzcameras',
#   'seller_score': 41966,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 202817400396,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + 24-105mm Lens Starter Bundle 01',
#   'item_price': 277153,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372478288069,
#   'item_title': 'Canon 5D Mark IV EOS Full Frame DSLR Camera with Zoom Intelligent TTL Flash Kit',
#   'item_price': 281900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 202893286088,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Full Frame Digital SLR Camera Body              #327',
#   'item_price': 47900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142428,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 192635276077,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera + 2 Lenses Pro Bundle 48',
#   'item_price': 540733,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 174050434540,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera Body Only-Low Shutter Count',
#   'item_price': 75000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'caogecym',
#   'seller_score': 14,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 183910925011,
#   'item_title': 'Canon EOS 5D Mark II 22.3 MP Digital SLR With Lens Flash Case Accessories',
#   'item_price': 130000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'modacolorata',
#   'seller_score': 685,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 274125005240,
#   'item_title': '【Exc/ShutterCount107907】 CANON EOS 5D Mark III body #519246',
#   'item_price': 110000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ridecamera_japan',
#   'seller_score': 285,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 264617250063,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black',
#   'item_price': 120000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yokev_o',
#   'seller_score': 192,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 112123875167,
#   'item_title': 'Canon EOS 5D S 5DS DSLR Camera (Body Only) 0581C002 Starter 32GB Bag Bundle',
#   'item_price': 121995,
#   'condition': 'New',
#   'items_sold': 4,
#   'seller_name': 'thepixelhub',
#   'seller_score': 54651,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 293450427552,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera (Kit w/ EF 24-105mm f/4L)',
#   'item_price': 299500,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'greylite',
#   'seller_score': 92,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 223602780944,
#   'item_title': 'Canon EOS 5D Mark IV 4 30.4MP Digital SLR Camera Black Body Only Excellent',
#   'item_price': 349999,
#   'condition': 'Used',
#   'items_sold': 1,
#   'seller_name': 'total-shop-japan-us',
#   'seller_score': 1567,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 371802132815,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body #1483C002',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': 9,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 352935434104,
#   'item_title': 'Canon EOS 5D Mark IV EF24-70 F4L IS USM Lens Kit -Near Mint- #28',
#   'item_price': 269200,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mapcamera',
#   'seller_score': 5156,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323748222555,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + FREE SIGMA  LENS, FLASH & BACKPACK- $2,999',
#   'item_price': 299999,
#   'condition': 'Open box',
#   'items_sold': None,
#   'seller_name': 'luvlummy1990',
#   'seller_score': 174,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 113830450284,
#   'item_title': 'Near Mint Canon EOS 5D Mark II 21.1MP Digital SLR Camera Body from Japan',
#   'item_price': 61000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'hidenobon_0',
#   'seller_score': 274,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 382075778396,
#   'item_title': 'Canon EOS  5D Mark IV DSLR Camera + 50mm 1.8 + EXT BAT + 2yr Warranty - 32GB Kit',
#   'item_price': 231898,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 332700903046,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera w/ 24-70mm IS USM Lens Memory & Flash Kit',
#   'item_price': 342900,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 254246652048,
#   'item_title': 'Canon Digital Camera EOS 5D MARK III (241901)',
#   'item_price': 140000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'macarthurecponline_1',
#   'seller_score': 615,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 1500},
#  {'sponsored': True,
#   'item_id': 392185057105,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body With Tripod Kit #1483C002 TP',
#   'item_price': 254900,
#   'condition': 'New',
#   'items_sold': 4,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 371997524250,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-70mm Lens with Free PC Accessory Bundle',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 292682160841,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body with Canon BG-E20 Battery Grip',
#   'item_price': 339800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 233465900673,
#   'item_title': 'CANON EOS 5D Mark II Full Frame 21.1MP DSLR Digital Camera from Japan Exc',
#   'item_price': 69301,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kazuro46',
#   'seller_score': 412,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 3900},
#  {'sponsored': True,
#   'item_id': 173871121474,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body + Lexar 128GB Card + MANUFACTURER WARRANTY',
#   'item_price': 339800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'ritzcameras',
#   'seller_score': 41966,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 402059240255,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 41500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rottnapples_closet',
#   'seller_score': 2,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 362903805414,
#   'item_title': '[Near Mint] Canon EOS 5D Mark III Body Camera From Japan + Free Shipping #5478',
#   'item_price': 115800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 332703439267,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body Shutter: 512',
#   'item_price': 279999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372351834251,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body Shutter: 584',
#   'item_price': 299999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 163860591278,
#   'item_title': 'ETSUMI LCD protective film ZERO PREMIUM Canon EOS 5D MarkIV dedicated E-7516',
#   'item_price': 48000,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'storesatisfactory',
#   'seller_score': 2423,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 2000},
#  {'sponsored': True,
#   'item_id': 223894094416,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera w/24-100 Lens + Many Extras',
#   'item_price': 125000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'blinaldi14',
#   'seller_score': 9,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 303333023911,
#   'item_title': 'Canon EOS 5D Mark III 22.3 MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 134000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'thepixelhub',
#   'seller_score': 54651,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372732463267,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-105mm USM Lens - With Canon 600EX II-RT FLash',
#   'item_price': 397800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323922751366,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP DSLR (Combo w/35mm f2 & Battery Grip) $1900+ Value',
#   'item_price': 130000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ianmcflysme',
#   'seller_score': 34,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 122663131826,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Video Creator Kit with Canon EF 24-105mm f/4L',
#   'item_price': 369900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 392594588142,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body with Canon Log With DJI Ronin-S Essentials Kit',
#   'item_price': 286900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372335077606,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-70mm Lens with Free Mac Accessory Bundle',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 392280117699,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-105mm Lens /Canon BG-E20 Battery W/Free Bundle',
#   'item_price': 369800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 293162196030,
#   'item_title': 'Canon EOS 5D Digital SLR Camera Body {12.8 M/P}',
#   'item_price': 32205,
#   'condition': 'Seller refurbished',
#   'items_sold': None,
#   'seller_name': 'kehoutlet',
#   'seller_score': 99351,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 323865333172,
#   'item_title': 'Canon EOS 5D Mark IV 30.4 MP DSLR Camera Body + 75-300mm & 50mm Two Lens Bundle',
#   'item_price': 272400,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372351836726,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body Shutter: 1499',
#   'item_price': 279999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 122499599166,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera Bundle (Body Only) + Accessories',
#   'item_price': 279900,
#   'condition': 'New',
#   'items_sold': 6,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 362432568205,
#   'item_title': 'Canon EOS 5D EF 24-70mm f/2.8L USM Pixma 9500 Quantom Flash Gitzo CB Bracket',
#   'item_price': 300000,
#   'condition': 'Open box',
#   'items_sold': None,
#   'seller_name': 'modeldetailer',
#   'seller_score': 22958,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 15000},
#  {'sponsored': True,
#   'item_id': 233385586213,
#   'item_title': 'Canon EOS 5D Digital SLR Camera Body from Japan',
#   'item_price': 34527,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'tokyo-shopping-time',
#   'seller_score': 1493,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 333163488013,
#   'item_title': 'Canon EOS 5D Mark IV DSLR with 24-70mm USM Lens /BG-E20 Battery Grip W/Free Kit',
#   'item_price': 354800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 153564215888,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 239998,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'rhhexchange99',
#   'seller_score': 180,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 273843937750,
#   'item_title': 'Excellent+ Canon EOS 5D 35mm DSLR Camera Body From Japan!! 102729',
#   'item_price': 29999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'satus-ibqauqn',
#   'seller_score': 563,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 4000},
#  {'sponsored': True,
#   'item_id': 192877823181,
#   'item_title': 'Canon EOS 5D 12.8MP Digital Camera Body From Kyoto Japan',
#   'item_price': 39900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'nexus_camera',
#   'seller_score': 540,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 333122187640,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + 24-70mm IS USM Lens & Canon Battery Grip Kit',
#   'item_price': 354800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 174013083126,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera - Black w/ 16-35mm EF Lens 2.8 ii',
#   'item_price': 384600,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'nbrowntown',
#   'seller_score': 95,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 7500},
#  {'sponsored': True,
#   'item_id': 192748636804,
#   'item_title': 'Canon EOS 5D Mark IV SLR Camera Body with Polaroid Track Slider Accessory Bundle',
#   'item_price': 309900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'ritzcameras',
#   'seller_score': 41966,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 362818920988,
#   'item_title': '[Near Mint] Canon EOS 5D Mark IV Body Digital Camera Working Tested From Japan',
#   'item_price': 243800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 362903825411,
#   'item_title': '[Near Mint] Canon EOS 5D Mark IV Body Camera From Japan + Free Shipping #5480',
#   'item_price': 233800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 312533832175,
#   'item_title': 'Canon 5D Mark IV Full Frame EOS DSLR Camera Pro Memory Power Recording Bundle',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 164067540003,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital Camera Body Shutter Count 21867 Excellent',
#   'item_price': 48900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'matsuiyastore',
#   'seller_score': 21165,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 124044113162,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera with Cap and Battery TESTED V18',
#   'item_price': 99500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'vssoutlet',
#   'seller_score': 6035,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 372297263519,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body With Free Mac Accessory Bundle #1483C002 AM',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 332336018151,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Body with Canon Log #1483C082',
#   'item_price': 259900,
#   'condition': 'New',
#   'items_sold': 4,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 282267561172,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body Only)',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': 10,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 173839451559,
#   'item_title': 'Canon EOS 5D Mark III DSLR + EF 24-105mm f/4L IS USM Lens +HOYA PRO1D UV Filter',
#   'item_price': 300000,
#   'condition': 'Seller refurbished',
#   'items_sold': None,
#   'seller_name': 'atmhpta',
#   'seller_score': 10,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': True,
#   'item_id': 372874659376,
#   'item_title': 'Canon EOS 5D Mark IV w/EF 24-70mm f/4L IS USM Lens W/BG-E20 Grip/Tripod Kit',
#   'item_price': 359800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': True,
#   'item_id': 293340739074,
#   'item_title': 'Canon EOS 5D Mark IV EF 24-105mm f/4L IS II USM Lens and Battery Grip Bundle',
#   'item_price': 449800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'focuscamera',
#   'seller_score': 121932,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0}]

# %%
def extractInfo_non(html):
    """
    The function takes the html file from non-sponsored and return a dictionary containing item information.
    
    PARAM str: html file name;
    
    RETURN dict: item_id, item_title, item_price, condition, items_sold, seller_name, seller_score,
                 best_offer, returns_allowed, shipping_cal, shipping_cost
    """
    soup_pgn = BeautifulSoup(open(os.getcwd() + "/non-sponsored/" + html))
    
    sponsored = False
    
    # get item id from the html file name
    item_id = int(re.search(r'[0-9]{12}', html)[0])
    
    # get the item title by looking at the first header with id=itemTitle, stripping out unwanted characters
    item_title = soup_pgn.find('h1',{'id':'itemTitle'}).get_text().replace('Details about  \xa0','').replace('\xa0','')
    
    # look for price summary span with id=prcIsum, when it is not in USD, use price in span with id=convbinPrice
    # when it is in USD, just use the price; or when it is on sale, use discounted price
    # for both situations, convert US dollars into US cents
    if soup_pgn.find('span',{'id':'prcIsum'}):
        if soup_pgn.find('span',{'id':'convbinPrice'}):
            raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'convbinPrice'}).get_text().strip().replace(',',''))[0]
            item_price = int(float(raw_price_text)*100)
        else:
            raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'prcIsum'}).get_text().strip().replace(',',''))[0]
            item_price = int(float(raw_price_text)*100)
    else:
        raw_price_text = re.search(r'[0-9]+.[0-9]+',soup_pgn.find('span',{'id':'mm-saleDscPrc'}).get_text().strip().replace(',',''))[0]
        item_price = int(float(raw_price_text)*100)
    
    # look for condition in div with id=vi-itm-cond, if not listed, return None.
    condition = None if soup_pgn.find('div',{'id':'vi-itm-cond'})==None else soup_pgn.find('div',{'id':'vi-itm-cond'}).get_text().strip()
    
    # look for item sold in span with a dedicated class attribute, convert into int, if not listed, return None.
    items_sold = None if soup_pgn.find('span', class_='vi-qtyS vi-bboxrev-dsplblk vi-qty-vert-algn vi-qty-pur-lnk')==None else int(soup_pgn.find('span', class_='vi-qtyS vi-bboxrev-dsplblk vi-qty-vert-algn vi-qty-pur-lnk').get_text().strip().replace(' sold',''))
    
    # look for seller name in span with class=mbg-nww, if not listed, return None.
    seller_name = None if soup_pgn.find('span', class_='mbg-nw')==None else soup_pgn.find('span', class_='mbg-nw').get_text()
    
    # look for seller_score in span with class=mbg-l, convert into int, if not listed, return None.
    seller_score = None if soup_pgn.findChild('span', class_='mbg-l').find('a')==None else int(soup_pgn.findChild('span', class_='mbg-l').find('a').get_text().strip())
    
    # look for better_offer availability in a with id=boBtn_btn, if not listed, return False.
    best_offer = False if soup_pgn.find('a',{'id':'boBtn_btn'})==None else True
    
    # look at the banner in span with id=vi-ret-accrd-txt, if it says not accept, return False, else True.
    if soup_pgn.find('span',{'id':'vi-ret-accrd-txt'}):
        if soup_pgn.find('span',{'id':'vi-ret-accrd-txt'}).get_text().strip()=='Seller does not accept returns':
            returns_allowed = False
        else:
            returns_allowed = True
    else:
        returns_allowed = True 
    
    # look for the shipping summary in the span with id=shSummary, if it says Calculate, return True, else False
    shipping_cal = True if soup_pgn.find('span',{'id':'shSummary'}).find('a').get_text()=='Calculate' else False
    # if shipping needs to be calculated, shipping cost is None
    if shipping_cal:
        shipping_cost = None
    # if not, look at the span with id=fshippingCost, 
    # if it says FREE, shipping cost=0, if not, return the US cents value for shipping
    elif soup_pgn.find('span',{'id':'fshippingCost'}):
            if soup_pgn.find('span',{'id':'fshippingCost'}).get_text().strip()=='FREE':
                shipping_cost = 0
            else:
                raw_text = soup_pgn.find('span',{'id':'fshippingCost'}).get_text().strip().replace(',','')
                shipping_cost = int(float(re.search(r'[0-9]+.[0-9]+', raw_text)[0])*100)
    # if it says fast and free, shipping cost=0
    elif soup_pgn.find('span',class_='vi-fnf-ship-txt fnfgreen'):
        shipping_cost = 0
    # if it is not in USD, use id=convetedPriceId, and return shipping cost in US cents
    elif soup_pgn.find('span',{'id':'convetedPriceId'}):
        raw_text = soup_pgn.find('span',{'id':'convetedPriceId'}).get_text().strip().replace(',','')
        shipping_cost = int(float(re.search(r'[0-9]+.[0-9]+', raw_text)[0])*100)
    # other situations like Local pick ups and needs contact seller, return None.
    else:
        shipping_cost = None    
    
    
    info_keys = ['sponsored','item_id', 'item_title', 'item_price', 'condition', 'items_sold', 'seller_name', 'seller_score',
                 'best_offer', 'returns_allowed', 'shipping_cal', 'shipping_cost']
    info_vals = [sponsored, item_id, item_title, item_price, condition, items_sold, seller_name, seller_score, best_offer,
                 returns_allowed, shipping_cal, shipping_cost]
    item_dict = {info_keys[i]: info_vals[i] for i in range(len(info_keys))}
    
    return item_dict

# %%
# creat a function to get a list of files in the directory. 
# Due to the macOS settings, there is a .DS_store file that interrupts the compilation.
nonsponsored_files = []
for file in os.listdir(os.getcwd() + "/non-sponsored/"):
    if file.endswith('.htm'):
        nonsponsored_files.append(file)

# %%
# nonsponsored items' info using parallel computing
p = Pool(12)  # Processing 12 files at a time.
nonsponsored_items_info = p.map(extractInfo_non, nonsponsored_files)
p.terminate()
p.join()
nonsponsored_items_info
# Out:
# [{'sponsored': False,
#   'item_id': 323574276084,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera with 24-105mm f/4L II Lens Bundle050',
#   'item_price': 289074,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 142380132444,
#   'item_title': 'New Year Deal Sale 5Dm4 Canon Eos 5D Mark Iv Dslr Camera Body M4 - 1483C002',
#   'item_price': 444800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'barterboxusa',
#   'seller_score': 1852,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 372814549865,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camera Body {22.3 M/P} (Count: 168,778)',
#   'item_price': 97755,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kehoutlet',
#   'seller_score': 99351,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 153800321650,
#   'item_title': 'Canon EOS 5D Mark 2 Digital SLR Camera AS IS',
#   'item_price': 35100,
#   'condition': 'For parts or not working',
#   'items_sold': None,
#   'seller_name': 'itelements',
#   'seller_score': 3113,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391916558903,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 70-300mm III + Pro Flash - 48GB Kit',
#   'item_price': 376299,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 124021571268,
#   'item_title': 'Canon EOS 5D Mark III 22.3 MP Full Frame CMOS with 1080p Full-HD Video Mode D...',
#   'item_price': 119375,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'tomats-12',
#   'seller_score': 33,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 183381801362,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only) (2764B003)',
#   'item_price': 70000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'd_gon',
#   'seller_score': 35,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 233266283391,
#   'item_title': 'Canon EOS 5D 12.8 MP Digital SLR Camera (Body Only) #C06183',
#   'item_price': 26999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'calagazphoto',
#   'seller_score': 6548,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1499},
#  {'sponsored': False,
#   'item_id': 123890982784,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body + Vivitar Trolley + 64GB x2 + Flash + More',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'photovideo4less',
#   'seller_score': 110665,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 302718457069,
#   'item_title': 'Canon EOS 5D Mark III - (Body Only)',
#   'item_price': 175000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ronnykumala',
#   'seller_score': 113,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352861320962,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 9PC Filter + Extra Battery - 32GB Kit',
#   'item_price': 384399,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 312534319992,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera - Black (Kit w/ EF L USM 24-70mm Lens)',
#   'item_price': 220000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mackmccul89',
#   'seller_score': 0,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 3000},
#  {'sponsored': False,
#   'item_id': 382269004293,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 50mm 1.4 USM + Battery Grip -48GB Kit',
#   'item_price': 394099,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 223895156271,
#   'item_title': 'Canon EOS 5D Mark III Camera - Black (Body Only) - See Description',
#   'item_price': 80000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'lensauthority',
#   'seller_score': 224,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 153821642868,
#   'item_title': 'Canon DS126201 EOS 5D Mark II 21.1MP Digital SLR Camera Body, Black #PU4834',
#   'item_price': 48390,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'profystore',
#   'seller_score': 29067,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 324025260054,
#   'item_title': 'Canon EOS 5D Mark IV MK 4 DSLR Digital SLR Camera Body With Accessories Bundle',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 122492954790,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera with Canon EF 24-105mm f/4L IS II USM kit',
#   'item_price': 389900,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 264624611489,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera body only',
#   'item_price': 15000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mayuska',
#   'seller_score': 986,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 283634551631,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera Body 30.4 MP Full-Frame (Body)',
#   'item_price': 209800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'jonggoo74',
#   'seller_score': 754,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1500},
#  {'sponsored': False,
#   'item_id': 283769415755,
#   'item_title': 'Canon EOS 5D Mark III 22.3 MP Digital SLR Camera 143k shots CHEAP!',
#   'item_price': 74931,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'thuong.nguyen.92',
#   'seller_score': 280,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 8000},
#  {'sponsored': False,
#   'item_id': 233472848650,
#   'item_title': 'Canon EOS 5D Mark IV Digital Camera with Canon EF 24-105 f/4 IS II USM Lens Kit',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'normancameracompanyllc',
#   'seller_score': 12738,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 191451410415,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera w/24-105mm Lens 16GB Package',
#   'item_price': 468972,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 183925008636,
#   'item_title': '(NEW) Canon EOS 5D Mark IV 4 30.4MP Digital SLR Camera Black Body from Japan',
#   'item_price': 360000,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'urag_jp',
#   'seller_score': 7,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 143460926922,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body                        #786',
#   'item_price': 105400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142429,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 124070284779,
#   'item_title': 'CANON EOS 5D Mark II Body Full Size Digital Camera Working Used',
#   'item_price': 53400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 153731384790,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - 85mm lens',
#   'item_price': 121200,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'carol_huntington',
#   'seller_score': 48,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 352198168159,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + Tulip Hood + Extra Battery - 48GB Kit',
#   'item_price': 357599,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 193333297965,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body Only 3 Piece Filter Kit (Intl Model) w/Can',
#   'item_price': 370212,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 283738098794,
#   'item_title': 'USED Canon EOS 5D 12.8MP Digital SLR Camera - Black Box  JAPAN 1884',
#   'item_price': 33000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ya_camera_japan001',
#   'seller_score': 1204,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352197328383,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + 6PC Graduated Filter - 96GB Bundle',
#   'item_price': 295299,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 164048786239,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 49000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'cyclone0318',
#   'seller_score': 17,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 163928498666,
#   'item_title': 'Canon5D MARK III 22.3 MP Digital SLR Camera 24-70mm f/4 L KIT 15k shutter ',
#   'item_price': 199900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kr503',
#   'seller_score': 199,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 392545468579,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 75-300mm III + 500-1300mm - 32GB Kit',
#   'item_price': 390699,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 323685363349,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera - Black Body',
#   'item_price': 42500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'fotoaffar',
#   'seller_score': 13105,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 2000},
#  {'sponsored': False,
#   'item_id': 382267651149,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm STM + 50mm f/1.4 USM + Remote - 48GB Kit',
#   'item_price': 320499,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391916560330,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 4PC Macro Kit + Extra Battery - 96GB',
#   'item_price': 357399,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 383277061537,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + Battery Grip + Extra Battery - 32GB',
#   'item_price': 384999,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 114097040260,
#   'item_title': 'CANON EOS 5D Mark II 21.1 Megapixel & Focusing Screen With Strap Used',
#   'item_price': 73800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 333408109260,
#   'item_title': 'Canon EOS 5D Mark ll',
#   'item_price': 50000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'jatexte',
#   'seller_score': 3,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 124066817421,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body + accessories ',
#   'item_price': 127229,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': '123.reptil9',
#   'seller_score': 935,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 2500},
#  {'sponsored': False,
#   'item_id': 223769242430,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black + Canon EF 28mm F1.8 USM',
#   'item_price': 49000,
#   'condition': 'For parts or not working',
#   'items_sold': None,
#   'seller_name': 'ynovikov',
#   'seller_score': 1865,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 3600},
#  {'sponsored': False,
#   'item_id': 333340745305,
#   'item_title': 'Canon EOS 5D Mark III in Excellent Condition',
#   'item_price': 119900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'treefrog40',
#   'seller_score': 590,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 333380919540,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera Body + BG-E6 Battery Grip JP',
#   'item_price': 46101,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'tokyo-shopping-time',
#   'seller_score': 1493,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 114097040249,
#   'item_title': 'CANON EOS 5D Mark II Digital Camera Working Used',
#   'item_price': 61400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 312949736059,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Full Frame Camera Body 5260B002',
#   'item_price': 91499,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'national_camera_outlet',
#   'seller_score': 5909,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 283754761882,
#   'item_title': 'Canon EOS 5D Mark III (Body Only) + Battery Grip',
#   'item_price': 87500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'livestrong283',
#   'seller_score': 23,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 113940055754,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 27500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'pabl_trueb',
#   'seller_score': 136,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 283432663783,
#   'item_title': 'CANON EOS 5D Mark IV Camera EF24-70L IS USM Lens Kit Japan Version New',
#   'item_price': 422197,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'maximumrare',
#   'seller_score': 956,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 262816400140,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera w/ 24-70mm 64GB Extreme PRO CompactFlash Bundle',
#   'item_price': 324995,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'truemodernelectronicsusa',
#   'seller_score': 7155,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 332047431564,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame DSLR Camera + EF 24-105mm f/4L IS II USM Lens',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 174177335997,
#   'item_title': 'Canon EOS 5D Mark III Digital Camera - Black (Body Only)',
#   'item_price': 86589,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'strawinscy',
#   'seller_score': 26,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 312749957258,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + 24-105mm + DJI Ronin-S Essential Gimbal Kit',
#   'item_price': 359900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 322837521411,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + 4 Lens Kit 28-75mm AF + 50mm + 32GB & More',
#   'item_price': 239994,
#   'condition': 'New',
#   'items_sold': 2,
#   'seller_name': 'redtagcamera',
#   'seller_score': 66819,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391915849336,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + Tamron 70-300mm + Remote -48GB Bundle',
#   'item_price': 310799,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 303221255527,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black',
#   'item_price': 100000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'nyc_photo',
#   'seller_score': 14,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 184132538374,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body 78,403 Clicks #052033001',
#   'item_price': 99999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'allenscamerashop',
#   'seller_score': 1929,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 193275029015,
#   'item_title': 'USED CANON EOS 5D MARK IV BODY',
#   'item_price': 172999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'whcamera',
#   'seller_score': 222,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 500},
#  {'sponsored': False,
#   'item_id': 112581421603,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body with EF 135mm f/2L USM Lens',
#   'item_price': 282900,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'deals-all-year',
#   'seller_score': 27936,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 402069914276,
#   'item_title': '[EXCELLENT] Canon EOS 5D Mark II 21.1MP Digital SLR Camera 2 Battery From Japan',
#   'item_price': 54900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'amfour_201810',
#   'seller_score': 183,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 192678887514,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body) + 256GB Memory Card (2X 128) + Canon...',
#   'item_price': 281870,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 193106694260,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body TT',
#   'item_price': 216319,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'yogadayogada',
#   'seller_score': 134913,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 324034592083,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 47500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'johnny28345',
#   'seller_score': 379,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 1200},
#  {'sponsored': False,
#   'item_id': 163989350337,
#   'item_title': 'Canon EOS 5D Mark II 21.1 MP Digital SLR Camera ',
#   'item_price': 110000,
#   'condition': 'Manufacturer refurbished',
#   'items_sold': None,
#   'seller_name': 'eds2ndhandstore',
#   'seller_score': 1234,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 254480869310,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 80000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'batmanjpb130',
#   'seller_score': 142,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 1500},
#  {'sponsored': False,
#   'item_id': 332027377577,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Full Frame 4K DSLR Camera Body + 64GB Pro Video Kit',
#   'item_price': 205994,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'redtagcamera',
#   'seller_score': 66819,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 312800664561,
#   'item_title': "Canon EOS 5D Digital SLR Camera Body w/ Original Owner's Manual - 18K Shutter",
#   'item_price': 34500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'silviosphotoworks',
#   'seller_score': 6695,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 333441601528,
#   'item_title': 'USED Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body',
#   'item_price': 114529,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_superstore',
#   'seller_score': 838,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 163533118765,
#   'item_title': ' Canon EOS 5D Mark IV Digital SLR Camera 32GB x2 Camera Bag Tripod Bundle',
#   'item_price': 200900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'deals-all-year',
#   'seller_score': 27936,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254503411093,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera  (DS126201) With 70-200 1:4 Lense',
#   'item_price': 85000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rockxr.inc',
#   'seller_score': 3457,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 830},
#  {'sponsored': False,
#   'item_id': 274247160306,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - New Shutter!',
#   'item_price': 83999,
#   'condition': 'Seller refurbished',
#   'items_sold': None,
#   'seller_name': 'nikon1960',
#   'seller_score': 369,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 193137140039,
#   'item_title': 'Canon EOS 5D Mark IV w/ 24-70mm f/4L IS USM',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'crutchfield_electronics',
#   'seller_score': 423,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 372842536056,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera with Flashpoint Zoom Li-On X TTL Speedlight',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': 'Adorama',
#   'seller_score': 525554,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 303147733006,
#   'item_title': 'High Speed Quick AC/DC Charger Kit for Canon EOS 5D Mark II DSLR Camera plus',
#   'item_price': 1587,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'hotdealselectronics',
#   'seller_score': 26287,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 192717995848,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera Body + 32GB Memory Card 1x 32 Bundle0044',
#   'item_price': 442220,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352197302184,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 24-105mm 4L IS II + Pro Flash + Batt Grip - 96GB',
#   'item_price': 300899,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 382075784545,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm 1.8 + 75-300mm III + 3PC Filter +2yr Warranty',
#   'item_price': 234298,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 312805024932,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Full Frame CMOS DSLR Camera (Body) WiFi NFC 4K Video',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254282395014,
#   'item_title': 'Canon EOS 5D + Canon EF 50mm f/1.8 II',
#   'item_price': 43000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ambience8-dnska',
#   'seller_score': 11,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5000},
#  {'sponsored': False,
#   'item_id': 162690223553,
#   'item_title': 'Canon EOS 5D Mark IV DSLR + 24-70mm f/2.8L II + 70-200mm f/2.8L IS III',
#   'item_price': 492400,
#   'condition': 'New',
#   'items_sold': 2,
#   'seller_name': 'deals-all-year',
#   'seller_score': 27936,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 332773160361,
#   'item_title': 'Canon EOS 5D Mark IV With 24-70mm f/2.8 L IS II USM + 70-200mm f/2.8 L IS II USM',
#   'item_price': 609900,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': '33rdstreetcamera',
#   'seller_score': 210,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254254953242,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 99900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'placidmonk',
#   'seller_score': 47,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 2900},
#  {'sponsored': False,
#   'item_id': 391915839214,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + Tamron 70-300mm + Backpack - 48GB Kit',
#   'item_price': 304899,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254479801077,
#   'item_title': 'Canon Eos 5D - Mark III',
#   'item_price': 150000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': '1adrenalin',
#   'seller_score': 476,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 7500},
#  {'sponsored': False,
#   'item_id': 112581421563,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera Body with 5 Year Extended Warranty',
#   'item_price': 231900,
#   'condition': 'New',
#   'items_sold': 4,
#   'seller_name': 'deals-all-year',
#   'seller_score': 27936,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 362905653209,
#   'item_title': 'Canon 5D Mark i Classic 12.8MP EOS Full Frame Battery Grip Extended Eyepiece',
#   'item_price': 30000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'jfunkngroove',
#   'seller_score': 160,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 401947871303,
#   'item_title': '^^ CANON EOS 5D MARK II DS126201 DIGITAL CAMERA (H1)',
#   'item_price': 100000,
#   'condition': 'For parts or not working',
#   'items_sold': None,
#   'seller_name': 'solanotraders',
#   'seller_score': 46062,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 1760},
#  {'sponsored': False,
#   'item_id': 183481765543,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera w/ 24-105mm f/4L II Lens + 8mm Fisheye Bundle',
#   'item_price': 389900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'photovideo4less',
#   'seller_score': 110665,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 361879450901,
#   'item_title': 'Canon EOS 5D Mark II 21.1 MP Digital SLR Camera - Black,Shutter Count:100',
#   'item_price': 69999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 392667835846,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera -Bundle',
#   'item_price': 120000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'temonadek_0',
#   'seller_score': 38,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 143432129972,
#   'item_title': 'Canon digital SLR camera EOS 5D MarkIV lens kit EF24-70 F2.8L EOS5DM4-2470ISLK',
#   'item_price': 800000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'masafuku-79',
#   'seller_score': 72,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 153684235131,
#   'item_title': 'Canon EOS 5D  Camera Body 12.8 MP Digital SLR  Good working',
#   'item_price': 26900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'lens_shop_japan',
#   'seller_score': 497,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391915847523,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + 500-1300mm + Extra Battery - 32GB Kit',
#   'item_price': 314799,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 402046304708,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera Kit w/ EF-S IS 28-135 Lens Fil Accs. EXC',
#   'item_price': 84999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'peddlemygear',
#   'seller_score': 4316,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 322322826207,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera Body 30.4 MP Full-Frame',
#   'item_price': 196995,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'redtagcamera',
#   'seller_score': 66819,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 201795726781,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + 8GB Memory Card & Case',
#   'item_price': 205060,
#   'condition': 'New',
#   'items_sold': 6,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 362903795329,
#   'item_title': '[Mint] Canon EOS 5D Mark IV Body Camera From Japan + Free Shipping #5476',
#   'item_price': 235800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391916516070,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm 2.8L II + Tamron 70-300mm + Slave Flash -48GB Kit',
#   'item_price': 373399,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 153817323919,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP 602 shutter count!!- WITH LENS AND MORE!',
#   'item_price': 220000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'alvar_macke',
#   'seller_score': 57,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 391916542435,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm 2.8L II + Tamron 70-300mm + LED Kit + Flash +48GB',
#   'item_price': 374399,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 382075927583,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm STM + 75-300mm + EXT BAT+ 32GB +2yr Warranty',
#   'item_price': 232398,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 323825621905,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only) ',
#   'item_price': 89900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'marlenev9909',
#   'seller_score': 44,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 283766287007,
#   'item_title': 'Canon EOS 5D II (SKU:938975)',
#   'item_price': 34400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mpbcom',
#   'seller_score': 4604,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 124070284815,
#   'item_title': 'CANON EOS 5D Mark II Body Digital Camera Working Used',
#   'item_price': 69600,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 382268962244,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 24-70mm f/2.8L II + Pro Flash + 9PC Filter + 96GB',
#   'item_price': 369299,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 333487793949,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera',
#   'item_price': 172900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'bitt72',
#   'seller_score': 4241,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 174168224693,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera Body ',
#   'item_price': 39900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'headonn72',
#   'seller_score': 82,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 124070284801,
#   'item_title': 'CANON EOS 5D Black & ZOOM LENS EF 28-80mm F3.5-5.6 ‡W USM',
#   'item_price': 56100,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 372899836223,
#   'item_title': 'Canon EOS 5D Mark IV Body w/64GB SDXC Card & Extra OEM Battery *NEW* *IN STOCK*',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'kenmorecamera',
#   'seller_score': 31291,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 143518711401,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body                        #448',
#   'item_price': 119800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142429,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 382075777020,
#   'item_title': 'Canon EOS  5D Mark IV DSLR Camera + 50mm 1.8 + Flash + 2yr Warranty - 64GB Kit',
#   'item_price': 232598,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 174111062879,
#   'item_title': 'CANON EOS 5D CAMERA DS126091 WITH ZOOM LENS EF 24-105MM L IS USM AND ACCESSORIES',
#   'item_price': 89999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'dylans-auctions',
#   'seller_score': 616,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 193332046510,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera EF Mount (Shutter Count 16131) #AA4834',
#   'item_price': 48499,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'aatstore',
#   'seller_score': 6515,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 193093627869,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera - Black (Body Only)-no charger',
#   'item_price': 239994,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'thepawnshop_miami',
#   'seller_score': 378,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 283464488771,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP DSLR Camera and Canon-EF-16-35mm-f-2-8-USM Lens',
#   'item_price': 110000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'write2afridy',
#   'seller_score': 170,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 361879488563,
#   'item_title': "Canon EOS 5D Mark II 21.1MP 3''Screen Digital SLR Camera - BODY ONLY",
#   'item_price': 43999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rongyuanxie',
#   'seller_score': 165739,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 322793224759,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camera (Body Only)',
#   'item_price': 381290,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 123148180319,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera (2) Lens Kit + Accessory Bundle',
#   'item_price': 292900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 323685281318,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body Only) + 64GB Kit + Replacement Battery',
#   'item_price': 206698,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tedselectronics1',
#   'seller_score': 17731,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 114097040263,
#   'item_title': 'CANON EOS 5D Mark II Body Used',
#   'item_price': 107100,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 283586126107,
#   'item_title': 'Canon Digital SLR Camera EOS 5D Mark III Body EOS 5DMK 3 [Used] F/S from Japan',
#   'item_price': 158905,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'fujiyama3776m',
#   'seller_score': 1807,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 114086764817,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera - Black + Zoom Lens + Accessories',
#   'item_price': 255000,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'parispi2011',
#   'seller_score': 12,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352197305762,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + Battery Grip + Extra Battery - 32GB',
#   'item_price': 316999,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 173947075205,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera Black Body Only',
#   'item_price': 39000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'anatolivasi-0',
#   'seller_score': 677,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 402031574128,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera Body with Altura Photo Complete Travel Bundle',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'digitalgoja',
#   'seller_score': 237246,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254484944429,
#   'item_title': 'Canon EOS 5D 12.8MP FFrm DSLR EF 28-135mm f3.5 Lens BG Grip 9K Clicks Exc++ Cnd',
#   'item_price': 59500,
#   'condition': 'Seller refurbished',
#   'items_sold': None,
#   'seller_name': 'ceastwoodpb17',
#   'seller_score': 333,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 312914038174,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP DSLR Camera Body + 64GB Memory & Flash Bundle',
#   'item_price': 279800,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'buydig',
#   'seller_score': 568352,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 192613866057,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black',
#   'item_price': 160000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'concreteproductionservices',
#   'seller_score': 39,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 323906535503,
#   'item_title': 'Canon EOS 5D DSLR +2 batteries, 4Gb CF memory card, 13,5k clicks, good condition',
#   'item_price': 38500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'cameraslensesetc',
#   'seller_score': 682,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1500},
#  {'sponsored': False,
#   'item_id': 333200599615,
#   'item_title': 'Canon EOS 5D Mark IV With 24-105mm f/4 L IS II USM + Tamron 70-300mm + Bundle',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '33rdstreetcamera',
#   'seller_score': 210,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352197323954,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + 50mm 1.4 USM + 500-1300mm - 32GB Kit',
#   'item_price': 340499,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 303444132367,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR - (Body Only) With Battery Grip',
#   'item_price': 200000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'amer22amer',
#   'seller_score': 121,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 174153872634,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera & 3 Lens Complete Package',
#   'item_price': 184900,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ngala5512',
#   'seller_score': 64,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 372911419348,
#   'item_title': 'Canon EOS 5Ds 50.6MP Digital SLR Camera Body #50',
#   'item_price': 134486,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mapcamera',
#   'seller_score': 5156,
# ...
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1500},
#  {'sponsored': False,
#   'item_id': 174167150250,
#   'item_title': 'Canon EOS 5D Mark II+ Canon 28-135mm 3.5-5.6 IS Lens + 32gb+16gb+16gb CF Card',
#   'item_price': 60000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'techtrading2000',
#   'seller_score': 58,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 233487027892,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camera Body + BONUS 2ND BATTERY',
#   'item_price': 95995,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'the.luxury.collection',
#   'seller_score': 1968,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 333396354223,
#   'item_title': 'Canon EOS 5D 12.8 MP Digital SLR Camera (Body Only) #L1288',
#   'item_price': 23399,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'calagazphoto',
#   'seller_score': 6548,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1499},
#  {'sponsored': False,
#   'item_id': 372693176778,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera Body {21.1 M/P}',
#   'item_price': 61464,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'kehoutlet',
#   'seller_score': 99351,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 382269004880,
#   'item_title': 'Canon EOS 5D Mark IV + 24-70mm f/2.8L II + 75-300mm III + LED + Pro Flash + 48GB',
#   'item_price': 377999,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 173981770974,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera (Body Only)',
#   'item_price': 198900,
#   'condition': 'New',
#   'items_sold': 4,
#   'seller_name': 'deal_expo',
#   'seller_score': 8198,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 283522837908,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - barely used as a back-up camera',
#   'item_price': 75000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'mtraicoff',
#   'seller_score': 26,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 252831521591,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera with 24-105mm f/4L II Lens- FREE 64GB SDXC Card',
#   'item_price': 349900,
#   'condition': 'New',
#   'items_sold': 9,
#   'seller_name': 'truemodernelectronicsusa',
#   'seller_score': 7155,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 114097040251,
#   'item_title': 'CANON EOS 5D Body Mark II Full Size Digital Camera Used',
#   'item_price': 58800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yashiroom',
#   'seller_score': 74,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 5900},
#  {'sponsored': False,
#   'item_id': 193318688373,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body in Box Nice! 22K Shutter Ct',
#   'item_price': 95950,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'yylc',
#   'seller_score': 848,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1795},
#  {'sponsored': False,
#   'item_id': 382177406118,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera + Canon EF 24-70 f/ 2.8L II USM Lens -64GB Kit',
#   'item_price': 355399,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 303343871447,
#   'item_title': 'Canon EOS 5D Mark IV 30.4MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 205000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 's.ramirez11',
#   'seller_score': 67,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391915828505,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + Tamron 70-300mm + 4PC Macro - 48GB',
#   'item_price': 299699,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391915831726,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm + Tamron 70-300mm + Slave Flash - 48GB Kit',
#   'item_price': 305699,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 254464026957,
#   'item_title': ' Canon EOS 5D Mark III DSLR DS126321 BLACK #CC1',
#   'item_price': 125000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'webuygoodscom',
#   'seller_score': 6887,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': True,
#   'shipping_cost': None},
#  {'sponsored': False,
#   'item_id': 372891816085,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Body Only',
#   'item_price': 39999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'Pawn America',
#   'seller_score': 166201,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 392584784408,
#   'item_title': 'Canon EOS 5D Mark IV w/24-70mm F/4L, 64GB SDXC & Extra OEM Battery *NEW*',
#   'item_price': 324900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'kenmorecamera',
#   'seller_score': 31291,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 352197319147,
#   'item_title': 'Canon EOS 5D Mark IV + 24-105mm 4L IS II + 50mm 1.4 USM + LED + Pro Flash + 48GB',
#   'item_price': 327699,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 372924889525,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camerawith Extras',
#   'item_price': 94800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'sergs1818',
#   'seller_score': 31,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 402068464997,
#   'item_title': 'Canon EOS 5D 12.8MP Full Frame Digital SLR Camera Body                      #992',
#   'item_price': 25700,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142429,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 123880741348,
#   'item_title': 'Canon EOS 5D 12.8 MP Digital SLR Camera (Body Only)',
#   'item_price': 49580,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'tomats-12',
#   'seller_score': 33,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 192963758436,
#   'item_title': 'Canon EOS 5D 12.8MP Digital SLR Camera - Black (Body Only) Factory Refurbished',
#   'item_price': 40000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'rhg1911',
#   'seller_score': 131,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 1900},
#  {'sponsored': False,
#   'item_id': 133326279080,
#   'item_title': 'Canon EOS 5D Mark II Digital SLR Camera *Shutter Count 9749*#25969 E2',
#   'item_price': 55000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'irohas',
#   'seller_score': 6390,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 293319008305,
#   'item_title': 'NEW Canon EOS 5D Mark IV 30.4 MP CMOS DSLR Camera + EF 24-70mm f/4L IS USM Lens',
#   'item_price': 249998,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'swingcomputers',
#   'seller_score': 7796,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 111730094229,
#   'item_title': 'Canon EOS 5DS / 5D S Digital SLR DSLR Camera (Body Only) Brand New',
#   'item_price': 129900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'deals-all-year',
#   'seller_score': 27936,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 153694440350,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera DS126201 / READ #BP4834',
#   'item_price': 39099,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'profystore',
#   'seller_score': 29067,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 173582168189,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera w/ 24-105mm f/4L II Lens + Battery Grip Bundle',
#   'item_price': 369995,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'photovideo4less',
#   'seller_score': 110665,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 233481917867,
#   'item_title': 'Canon EOS 5D Mark II DS126201 - 21.1MP Digital SLR Camera Body #UM4834',
#   'item_price': 46490,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'unistore2015',
#   'seller_score': 4840,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 143463055351,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera Body                        #404',
#   'item_price': 105400,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'robertscamera',
#   'seller_score': 142429,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 362903828308,
#   'item_title': '[Mint] Canon EOS 5D Mark III Body Camera From Japan + Free Shipping #5481',
#   'item_price': 149800,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'japan_camera_bureau',
#   'seller_score': 566,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 391778424799,
#   'item_title': 'Canon EOS 5D Mark IV Camera + 50mm STM  + 2yr Warranty -Ultimate Saving Bundle',
#   'item_price': 225298,
#   'condition': 'New',
#   'items_sold': 3,
#   'seller_name': 'tri-state-camera',
#   'seller_score': 114099,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 201243649017,
#   'item_title': 'Canon EOS 5D Mark III DSLR Camera w/24-105mm Lens 32GB Package',
#   'item_price': 469347,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 193277647533,
#   'item_title': 'Canon EOS 5D Mark II DSLR Camera, Grip, 2x Batteries, Original Box (Excellent)',
#   'item_price': 62500,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'backmenuinfo',
#   'seller_score': 31,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 303387454891,
#   'item_title': 'Canon EOS 5D Mark III kit bundle with JuicedLink RA202, used',
#   'item_price': 143576,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'digibcltd',
#   'seller_score': 874,
#   'best_offer': True,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 15000},
#  {'sponsored': False,
#   'item_id': 303473762430,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 60000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'sam_912464',
#   'seller_score': 0,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 333243489093,
#   'item_title': 'Canon EOS 5D 12.8 MP Digital SLR Camera (Body Only) #C001771',
#   'item_price': 24299,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'calagazphoto',
#   'seller_score': 6548,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 1299},
#  {'sponsored': False,
#   'item_id': 274129781243,
#   'item_title': 'Canon EOS 5D Mark III Digital SLR Camera (Body Only)',
#   'item_price': 119999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'lsubeano',
#   'seller_score': 44,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 223883296289,
#   'item_title': 'Canon EOS 5D Mark II 21.1MP Digital SLR Camera with 24-105mm f/4L IS USM Lens',
#   'item_price': 149998,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'oracle336-2',
#   'seller_score': 381,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 183903142757,
#   'item_title': 'Canon EOS 5D Mark IV Full Frame Digital SLR Camera Body',
#   'item_price': 249900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'photovideo4less',
#   'seller_score': 110665,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 174078626848,
#   'item_title': 'Canon EOS 5D Mark III 22.3MP Digital SLR Camera - Black (Body Only)',
#   'item_price': 110000,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'ridekawi217',
#   'seller_score': 29,
#   'best_offer': False,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 2000},
#  {'sponsored': False,
#   'item_id': 122492889701,
#   'item_title': 'Canon EOS 5D Mark IV Digital SLR Camera Bundle with EF 24-105mm f/4L IS II USM',
#   'item_price': 369900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 192717995850,
#   'item_title': 'Canon EOS 5D Mark IV DSLR Camera (Body) + Canon 17-40mm Lens Wide Angle Combo',
#   'item_price': 262326,
#   'condition': 'New',
#   'items_sold': 1,
#   'seller_name': '6ave',
#   'seller_score': 63650,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 123214148182,
#   'item_title': 'Canon EOS 5d Mark IV DSLR Camera Video Creator Kit with Canon 24-105mm STM Lens',
#   'item_price': 339900,
#   'condition': 'New',
#   'items_sold': None,
#   'seller_name': 'pagingzone',
#   'seller_score': 594,
#   'best_offer': False,
#   'returns_allowed': True,
#   'shipping_cal': False,
#   'shipping_cost': 0},
#  {'sponsored': False,
#   'item_id': 273963634074,
#   'item_title': 'Canon EOS 5D 12.8 MP Digital SLR Camera - Body Only (0296B002)',
#   'item_price': 129999,
#   'condition': 'Used',
#   'items_sold': None,
#   'seller_name': 'pcmonde',
#   'seller_score': 8304,
#   'best_offer': True,
#   'returns_allowed': False,
#   'shipping_cal': False,
#   'shipping_cost': 0}]

# %% [markdown]
# ## Get items into SQLDB

# %%
# Connect to the sql server
pw = "" # please insert your server password here
conn = pymysql.connect(host='localhost', user = 'root', password = pw)
cursor = conn.cursor()
# Create database eBay
SQL_DB = "eBay"
cursor.execute('DROP DATABASE IF EXISTS ' + SQL_DB)
query_DB = "CREATE DATABASE IF NOT EXISTS " + SQL_DB + ";"
cursor.execute(query_DB)
cursor.close()
conn.close()

# %%
# Create SQL DB and table, insert item information
conn = pymysql.connect(host='localhost', user = 'root', password = pw, database=SQL_DB)
cursor = conn.cursor()
cursor.execute('DROP TABLE IF EXISTS %s' % ('eBay_items'))

# Query to create table eBay_items in DB
sql = '''
        CREATE TABLE IF NOT EXISTS eBay_items
       (
       sponsored VARCHAR(255),
       item_id BIGINT PRIMARY KEY,
       item_title VARCHAR(255),
       item_price INT(11),
       conditions VARCHAR(255),
       items_sold INT(11),
       seller_name VARCHAR(255),
       seller_score INT(11),
       best_offer VARCHAR(255),
       returns_allowed VARCHAR(255),
       shipping_cal VARCHAR(255),
       shipping_cost INT(11)
       );
      '''
cursor.execute(sql)

# Query to insert data
q = """
    INSERT INTO eBay_items (sponsored, item_id, item_title, item_price, conditions, items_sold, seller_name, 
    seller_score, best_offer, returns_allowed, shipping_cal, shipping_cost)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
    """
# loop through the list of dictionaries and insert data accordingly to the table
for item in sponsored_items_info:
    vals = (item['sponsored'],item['item_id'],item['item_title'],item['item_price'],item['condition'],
           item['items_sold'],item['seller_name'],item['seller_score'],item['best_offer'],item['returns_allowed'],
           item['shipping_cal'],item['shipping_cost'])
    cursor.execute(q, vals)
    conn.commit()

for item in nonsponsored_items_info:
    vals = (item['sponsored'],item['item_id'],item['item_title'],item['item_price'],item['condition'],
          item['items_sold'],item['seller_name'],item['seller_score'],item['best_offer'],item['returns_allowed'],
           item['shipping_cal'],item['shipping_cost'])
    cursor.execute(q, vals)
    conn.commit()

cursor.close()
conn.close()

# %% [markdown]
# ## Summary stats on each item.

# %%
def getSummaryStats():
    """
    The function runs queries to retrieve summary stats from mysql DB.
    
    RETURN: DataFrames of summary stats for AVG, STD, MIN and MAX.
    """
    
    conn = pymysql.connect(host='localhost', user = 'root', password = pw, database=SQL_DB)
    
    # getting AVG
    query_avg = """
                SELECT sponsored, conditions, 
                AVG(item_price) AS avg_price,
                AVG(items_sold) AS avg_sold,
                AVG(seller_score) AS avg_seller_score,
                AVG(best_offer) AS avg_best_offer,
                AVG(returns_allowed) AS avg_returns_allowed,
                AVG(shipping_cost) AS avg_shipping_cost
                FROM eBay_items
                GROUP BY sponsored, conditions
                ORDER BY sponsored, conditions
                """
    df_avg = pd.read_sql_query(query_avg, conn)
    
    # getting STD
    query_std = """
                SELECT sponsored, conditions, 
                STD(item_price) AS std_price,
                STD(items_sold) AS std_sold,
                STD(seller_score) AS std_seller_score,
                STD(best_offer) AS std_best_offer,
                STD(returns_allowed) AS std_returns_allowed,
                STD(shipping_cost) AS std_shipping_cost
                FROM eBay_items
                GROUP BY sponsored, conditions
                ORDER BY sponsored, conditions
                """
    df_std = pd.read_sql_query(query_std, conn)
    
    # getting MIN
    query_min = """
                SELECT sponsored, conditions, 
                MIN(item_price) AS min_price,
                MIN(items_sold) AS min_sold,
                MIN(seller_score) AS min_seller_score,
                MIN(best_offer) AS min_best_offer,
                MIN(returns_allowed) AS min_returns_allowed,
                MIN(shipping_cost) AS min_shipping_cost
                FROM eBay_items
                GROUP BY sponsored, conditions
                ORDER BY sponsored, conditions
                """
    df_min = pd.read_sql_query(query_min, conn)
    
    # getting MAX
    query_max = """
                SELECT sponsored, conditions, 
                MAX(item_price) AS max_price,
                MAX(items_sold) AS max_sold,
                MAX(seller_score) AS max_seller_score,
                MAX(best_offer) AS max_best_offer,
                MAX(returns_allowed) AS max_returns_allowed,
                MAX(shipping_cost) AS max_shipping_cost
                FROM eBay_items
                GROUP BY sponsored, conditions
                ORDER BY sponsored, conditions
                """
    df_max = pd.read_sql_query(query_max, conn)
    conn.close()
    
    return df_avg, df_std, df_min, df_max

# %%
df_AVG, df_STD, df_MIN, df_MAX = getSummaryStats()

# %%
# print AVG stats
df_AVG
# Out:
#   sponsored                conditions    avg_price  avg_sold  \
# 0         0  For parts or not working   41720.2000       NaN
# 1         0  Manufacturer refurbished  104950.0000       NaN
# 2         0                       New  306085.8926    2.8491
# 3         0                  Open box  243070.0000       NaN
# 4         0        Seller refurbished  108402.2222    3.0000
# 5         0                      Used  107693.4768    1.4000
# 6         1                       New  305000.1452    4.0000
# 7         1                  Open box  268102.3333       NaN
# 8         1        Seller refurbished  132838.3333       NaN
# 9         1                      Used  144557.5833    1.0000
#
#    avg_seller_score  avg_best_offer  avg_returns_allowed  avg_shipping_cost
# 0         4493.2000        0.466667             0.066667          1572.1818
# 1          802.0000        0.500000             0.000000                NaN
# 2        94937.9843        0.029083             0.941834            80.5869
# 3        16139.7059        0.352941             0.529412           707.0714
# 4        44444.0000        0.222222             0.555556           251.4286
# 5        11007.6909        0.438384             0.551515          1267.2323
# 6       270410.9032        0.048387             0.983871            32.7869
# 7        28927.3333        0.666667             0.666667          7500.0000
# 8        66237.3333        0.000000             0.666667             0.0000
# 9        22059.3542        0.395833             0.750000          1533.6977

# %%
# print STD stats
df_STD
# Out:
#   sponsored                conditions      std_price  std_sold  \
# 0         0  For parts or not working   31159.199791       NaN
# 1         0  Manufacturer refurbished    5050.000000       NaN
# 2         0                       New   93608.818116  2.157884
# 3         0                  Open box  102057.950809       NaN
# 4         0        Seller refurbished   57070.595180  0.000000
# 5         0                      Used   77410.851078  0.800000
# 6         1                       New   79079.468925  3.043544
# 7         1                  Open box   45109.405703       NaN
# 8         1        Seller refurbished  119018.359531       NaN
# 9         1                      Used  105211.475736  0.000000
#
#    std_seller_score  std_best_offer  std_returns_allowed  std_shipping_cost
# 0      11218.449211        0.498888             0.249444        1534.942037
# 1        432.000000        0.500000             0.000000                NaN
# 2     126930.032112        0.168039             0.234056         619.351309
# 3      26506.206287        0.477885             0.499134        1245.096122
# 4      49113.004044        0.415740             0.496904         615.871707
# 5      34306.373050        0.496189             0.497339        2292.406696
# 6     228028.502792        0.214583             0.125972         253.966121
# 7      26255.480054        0.471405             0.471405        7500.000000
# 8      46829.796500        0.000000             0.471405           0.000000
# 9      52166.315114        0.489029             0.433013        2284.609137

# %%
# print MIN stats
df_MIN
# Out:
#   sponsored                conditions  min_price  min_sold  min_seller_score  \
# 0         0  For parts or not working       9999       NaN                 0
# 1         0  Manufacturer refurbished      99900       NaN               370
# 2         0                       New       1587       1.0                 1
# 3         0                  Open box       2820       NaN                 9
# 4         0        Seller refurbished      31160       3.0                 9
# 5         0                      Used      14940       1.0                 0
# 6         1                       New      48000       1.0                 0
# 7         1                  Open box     204308       NaN               174
# 8         1        Seller refurbished      32205       NaN                10
# 9         1                      Used      22900       1.0                 2
#
#   min_best_offer min_returns_allowed  min_shipping_cost
# 0              0                   0                0.0
# 1              0                   0                NaN
# 2              0                   0                0.0
# 3              0                   0                0.0
# 4              0                   0                0.0
# 5              0                   0                0.0
# 6              0                   0                0.0
# 7              0                   0                0.0
# 8              0                   0                0.0
# 9              0                   0                0.0

# %%
# print MAX stats
df_MAX
# Out:
#   sponsored                conditions  max_price  max_sold  max_seller_score  \
# 0         0  For parts or not working     127999       NaN             46062
# 1         0  Manufacturer refurbished     110000       NaN              1234
# 2         0                       New     640000      10.0            916794
# 3         0                  Open box     468900       NaN             63650
# 4         0        Seller refurbished     198599       3.0             99351
# 5         0                      Used     800000       3.0            166201
# 6         1                       New     540733      10.0            568352
# 7         1                  Open box     300000       NaN             63650
# 8         1        Seller refurbished     300000       NaN             99351
# 9         1                      Used     384600       1.0            165739
#
#   max_best_offer max_returns_allowed  max_shipping_cost
# 0              1                   1             3600.0
# 1              1                   0                NaN
# 2              1                   1             7500.0
# 3              1                   1             3500.0
# 4              1                   1             1760.0
# 5              1                   1            15000.0
# 6              1                   1             2000.0
# 7              1                   1            15000.0
# 8              0                   1                0.0
# 9              1                   1             7500.0

# %% [markdown]
# By looking at the summary stats, on average, sponsored items tend to have higher seller score, have higher shipping cost, and to be priced higher and more generous offering free returns. <br>
#
# The minimum price of sponored items is always higher than that of the non-sponsored items, while the max price being noticeably lower. <br>
#
# To predict the sponsor/non-sponsor items (in this case the Canon EOS 5D DSLR Camera), the min/max item price, seller score, and whether offering returns are some good predictor features after initial glance at the data statistics.
